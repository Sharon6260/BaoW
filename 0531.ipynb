# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharon6260/BaoW/blob/main/0531.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("hi")
# Out:
# hi

# %%
print("rjiw")
# Out:
# rjiw

# %% [markdown]
# # 這是第一節上課
